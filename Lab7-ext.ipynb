# %% [markdown]
# # Lab Assignment Seven: Recurrent Network Architectures

# %% [markdown]
# ## Dataset Selection
#
# Select a dataset that is text. That is, the dataset should be text data (or a time series sequence). In terms of generalization performance, it is helpful to have a large dataset of similar sized text documents. It is fine to perform binary classification or multi-class classification. The classification can be "many-to-one" or "many-to-many" sequence classification, whichever you feel more comfortable with.

# %% [markdown]
# It's a dataset I got from [kaggle](https://www.kaggle.com/kazanova/sentiment140). Sentiment140 dataset with 1.6 million tweets, which was collected by twitter API.

# %% [markdown]
# ## 1 Preparation (3 points total)
# - [1 points] Define and prepare your class variables. Use proper variable representations (int, float, one-hot, etc.). Use pre-processing methods (as needed). Describe the final dataset that is used for classification/regression (include a description of any newly formed variables you created). Discuss methods of tokenization in your dataset as well as any decisions to force a specific length of sequence.
# - [1 points] Choose and explain what metric(s) you will use to evaluate your algorithm’s performance. You should give a detailed argument for why this (these) metric(s) are appropriate on your data. That is, why is the metric appropriate for the task (e.g., in terms of the business case for the task). Please note: rarely is accuracy the best evaluation metric to use. Think deeply about an appropriate measure of performance.
# - [1 points] Choose the method you will use for dividing your data into training and testing (i.e., are you using Stratified 10-fold cross validation? Shuffle splits? Why?). Explain why your chosen method is appropriate or use more than one method as appropriate. Convince me that your train/test splitting method is a realistic mirroring of how an algorithm would be used in practice.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from scipy.special import expit
from sklearn.model_selection import train_test_split
import copy
from sklearn.model_selection import ShuffleSplit
from sklearn import metrics as mt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
import sys
import os
import tempfile
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold, ShuffleSplit
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import make_scorer, accuracy_score, roc_curve, auc
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn import metrics as mt
from sklearn.impute import KNNImputer
from tensorflow.keras.layers import Dense, Activation, Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import concatenate
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adagrad,Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, SimpleRNN, Conv1D, MaxPooling1D
from tensorflow.keras.layers import LSTM, GRU, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

print('tensorflow version:',tf.__version__)
print('pandas version:',pd.__version__)
print('keras version:',keras.__version__)
print('numpy version:',np.__version__)

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
# Out:
# tensorflow version: 2.6.0
# pandas version: 1.3.4
# keras version: 2.6.0
# numpy version: 1.19.5

# %% [markdown]
# ### 1.1 Define and prepare your class variables. Use proper variable representations (int, float, one-hot, etc.). Use pre-processing methods (as needed). Describe the final dataset that is used for classification/regression (include a description of any newly formed variables you created). Discuss methods of tokenization in your dataset as well as any decisions to force a specific length of sequence.

# %% [markdown]
# ### It's a large dataset contained 1.6 million rows, but I use only 100 thousand rows each of a class(positive, negative) for computational efficiency. I have tried a more larger dataset, but only for my first one rnn model it's fast in computation because it meets the requirement of using a fast cuDNN implementation. By the way, the language this dataset used is English so I don't need to care about other language.

# %%
# %%time
chunk_size = 50000
chunks = pd.read_csv('./data/sentiment140.csv',names=['target','ids','date','flag','user','text'],usecols=['target','text'],iterator=True,chunksize=chunk_size, encoding="latin-1")
get_pos = False
get_neg = False
for chunk in chunks:
    if ~get_pos and (chunk['target']==4).all():
        chunka = chunk
        get_pos = True
    if ~get_neg and (chunk['target']==0).all():
        chunkb = chunk
        get_neg = True
    if  get_pos and get_neg:
        break

df = pd.concat([chunka,chunkb])
df['target'].replace(4,1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 800000 to 799999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   target  100000 non-null  int64
#  1   text    100000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 2.3+ MB
# CPU times: user 625 ms, sys: 55.3 ms, total: 681 ms
# Wall time: 680 ms

# %% [markdown]
# ### There are not NA data in this data set.

# %%
df.isna().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.target.value_counts()
# Out:
# 1    50000
# 0    50000
# Name: target, dtype: int64

# %% [markdown]
# ### I need to lowercase the letters, so a word contained the same characters could be recongized as the same. Then I remove the url, @userName, punctuations and stop words for the benifit of dimensionality reduction, because they are not essential to the sentiment analysis.

# %%
import re
import string
urlPattern = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
userPattern = '@[^\s]+'

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

STOPWORDS = set(stopwords.words('english'))

def process_text(text_data):
    #make string lower-case
    text_data = text_data.lower()
    #remove url
    text_data = re.sub(urlPattern,'',text_data)
    #remove all @username
    text_data = re.sub(userPattern,'',text_data)
    #remove punctuations
    text_data = text_data.translate(str.maketrans("","",string.punctuation))
    #remove stop words
    tokens = []
    for token in text_data.split():
        if token not in STOPWORDS:
            tokens.append(token)
        
    return " ".join(tokens)
# Out:
# [nltk_data] Downloading package stopwords to /Users/Amor/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['text'] = df.text.apply(lambda x: process_text(x))

# %% [markdown]
# ### Besides, I would like to remove the stop words here since they are also trivial to the sentiment analysis.

# %% [markdown]
# ### my final dataset is organized as follows:
#
# |Variable | description|
# |----|--------|
# |target:      |0 as negative, 1 as positive.|
# |text:      |text from tweet|
#
#
# ### I use this dataset to identify whether a tweet is positive or negative, so it's a binary classification task.

# %%
df.head()
# Out:
#         target                                               text
# 800000       1                                 love u guys r best
# 800001       1  im meeting one besties tonight cant wait girl ...
# 800002       1  thanks twitter add sunisa got meet hin show dc...
# 800003       1  sick really cheap hurts much eat real food plu...
# 800004       1                                    effect everyone

# %% [markdown]
# ### I would use word tokenization with a specific length of sequence. The reason I used word tokenization is because it's most common method and I want to focus the meaning of the word to do sentiment analysis. The forced specific length of sequence is due to computational efficiency by using only one computation graph.

# %%
# %%time
NUM_TOP_WORDS = None # use entire words
MAX_ART_LEN = 35

#tokenize the text
tokenizer = Tokenizer(num_words=NUM_TOP_WORDS)
tokenizer.fit_on_texts(df.text)
# save as sequences with integers replacing words
sequences = tokenizer.texts_to_sequences(df.text)

word_index = tokenizer.word_index
NUM_TOP_WORDS = len(word_index) if NUM_TOP_WORDS==None else NUM_TOP_WORDS
top_words = min((len(word_index),NUM_TOP_WORDS))
print('Found %s unique tokens. Distilled to %d top words.' % (len(word_index),top_words))

X = pad_sequences(sequences,maxlen=MAX_ART_LEN)
y = df.target
print('Shape of data tensor:', X.shape)
print('Shape of label tensor:', y.shape)
print(np.max(X))
# Out:
# Found 66640 unique tokens. Distilled to 66640 top words.
# Shape of data tensor: (100000, 35)
# Shape of label tensor: (100000,)
# 66640
# CPU times: user 1.4 s, sys: 15.7 ms, total: 1.41 s
# Wall time: 1.42 s

# %% [markdown]
# ### 1.2 Choose and explain what metric(s) you will use to evaluate your algorithm’s performance. You should give a detailed argument for why this (these) metric(s) are appropriate on your data. That is, why is the metric appropriate for the task (e.g., in terms of the business case for the task). Please note: rarely is accuracy the best evaluation metric to use. Think deeply about an appropriate measure of performance.

# %% [markdown]
# ### I would use both accuracy and F1 score as the metrics for my classification task. The accuracy is straightforward and intuitive to directly compare with different algorithms and also because the dataset is even in classes distribution. In addition, 80%-85% accuracy is a baseline that human analysts agree with for the sentiment analysis, which , so I may try to meet the baseline on my best model.
# ### F1 score, as the harmonic mean of recall and precision, considers equally important the effectiveness in each class independently of the relative size of the class. Hence,  accuracy and F1 score provide complementary assessments of the classification effectiveness.

# %%
plt.hist(y,bins=4)
# Out:
# (array([50000.,     0.,     0., 50000.]),
#  array([0.  , 0.25, 0.5 , 0.75, 1.  ]),
#  <BarContainer object of 4 artists>)

# %% [markdown]
# ### 1.3 Choose the method you will use for dividing your data into training and testing (i.e., are you using Stratified 10-fold cross validation? Shuffle splits? Why?). Explain why your chosen method is appropriate or use more than one method as appropriate. Convince me that your train/test splitting method is a realistic mirroring of how an algorithm would be used in practice.

# %% [markdown]
# ### Though the original dataset is 1.6 million, I used 200 thousand of them because most of my RNN models can't run under a fast cuDNN implementation since it has strict requirement(The first model of LSTM and GRU, they can be trained fast because of using cuDNN implementation), which makes the training a long period. Besides, I think 200 thousand is big enough for me to safely use 80-20 traning and testing split and also because of this totally balanced dataset.
#
# ### Besides, to improve computational efficiency, I do not use K-fold here though I think it is good idea to evaluate my model.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=30)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (80000, 35)
# (20000, 35)
# (80000,)
# (20000,)

# %% [markdown]
# ## 2. Modeling (6 points total)
# - [3 points] Investigate at least two different recurrent network architectures (perhaps LSTM and GRU). Be sure to use an embedding layer (pre-trained, from scratch, OR both). Adjust hyper-parameters of the networks as needed to improve generalization performance (train a total of at least four models). Discuss the performance of each network and compare them.
# - [1 points] Using the best RNN parameters and architecture, add a second recurrent chain to your RNN. The input to the second chain should be the output sequence of the first chain. Visualize the performance of training and validation sets versus the training iterations.
# - [2 points] Use the method of train/test splitting and evaluation criteria that you argued for at the beginning of the lab. Visualize the results of all the RNNs you trained.  Use proper statistical comparison techniques to determine which method(s) is (are) superior.

# %% [markdown]
# ### During the training, I use early stopping by monitoring the val_loss with patience=10 and reducing the learning rate by monitoring val_loss with patience 5 in order to prevent overfitting.

# %%
def plot_metrics(history,label):
    metrics = ['loss', 'accuracy']
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        # plt.subplot(2,2,n+1)
        plt.plot(history.epoch, history.history[metric], label='Train ' + label)
        plt.plot(history.epoch, history.history['val_'+metric],linestyle="--", label='Val ' + label)
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric != 'loss':
            plt.ylim([0,1])
        plt.title('{}'.format(metric))
        plt.legend()
        plt.show()

def evaluate_model(model,X_train,y_train,X_test,y_test,model_name,epochs=100,batch_size=128,verbose=1): 
    h = model.fit(X_train,
        y_train, 
        epochs=epochs, 
        verbose=verbose,
        batch_size=batch_size,
        shuffle=True,
        callbacks=[EarlyStopping(monitor = 'val_loss', patience = 6),ReduceLROnPlateau(monitor='val_loss', patience=3)],
        validation_data=(X_test, y_test)
    )
    plot_metrics(h,model_name)
    # now lets see how well the model performed
    yscore = model.predict(X_test).flatten()
    yhat = np.around(yscore)
    acc = mt.accuracy_score(y_test,yhat)
    fp,tp,_ = mt.roc_curve(y_test,yscore)
    f1_score = mt.f1_score(y_test,yhat)
    # cm = mt.confusion_matrix(y_test,yhat)
    cm = mt.confusion_matrix(y_test,yhat)
    cm = cm/np.sum(cm,axis=1)[:,np.newaxis]
    sns.heatmap(cm, annot = True,fmt = '.2f')
    plt.title('{}: acc={:.4f}, f1={:.4f}'.format(model_name,acc,f1_score))
    plt.show()
    print(classification_report(y_test,yhat))
    return {'history':h,'cm':cm,'acc':acc,'fp':fp, 'tp':tp, 'f1':f1_score}

# %%
def compare_model(model1_eval,model2_eval,model1_name,model2_name):
    fp1 = model1_eval['fp']
    tp1 = model1_eval['tp']
    fp2 = model2_eval['fp']
    tp2 = model2_eval['tp']
    plt.plot(fp1, tp1, label='{} ROC (AUC {:.3f})'.format(model1_name,auc(fp1,tp1)) , linewidth=2)
    plt.plot(fp2, tp2, label='{} ROC (AUC {:.3f})'.format(model2_name,auc(fp2,tp2)), linewidth=2, linestyle='--')
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.grid(True)
    ax = plt.gca()
    # ax.set_aspect('equal')
    plt.legend(loc='best')
    plt.show()

    plt.figure(figsize=(15,5))
    acc1 = model1_eval['acc']
    acc2 = model2_eval['acc']
    f1_1 = model1_eval['f1']
    f1_2 = model2_eval['f1']
    cm1 = model1_eval['cm']
    # cm1 = cm1/np.sum(cm1,axis=1)[:,np.newaxis]
    cm2 = model2_eval['cm']
    # cm2 = cm2/np.sum(cm2,axis=1)[:,np.newaxis]

    plt.subplot(1,2,1)
    sns.heatmap(cm1, annot=True, fmt='.2f')
    plt.title('{}: acc={:.4f}, f1={:.4f}'.format(model1_name,acc1,f1_1))

    plt.subplot(1,2,2)
    sns.heatmap(cm2, annot=True, fmt='.2f')
    plt.title('{}: acc={:.4f}, f1={:.4f}'.format(model2_name,acc2,f1_2))

    plt.show()

    d = np.abs(acc1-acc2)
    v = acc1*(1-acc1)/X_test.shape[0] + acc2*(1-acc2)/X_test.shape[0]
    print('The difference on accuracy of {} and {} is {},{} '.format(model1_name,model2_name,d-1.96*np.sqrt(v),d+1.96*np.sqrt(v)))

    d = np.abs(f1_1-f1_2)
    v = f1_1*(1-f1_1)/X_test.shape[0] + f1_2*(1-f1_2)/X_test.shape[0]
    print('The difference on f1 score of {} and {} is {},{} '.format(model1_name,model2_name,d-1.96*np.sqrt(v),d+1.96*np.sqrt(v)))

# %% [markdown]
# ### I used an pre-trained GloVe embedding

# %%
# %%time
EMBED_SIZE = 300
# the embed size should match the file you load glove from
embeddings_index = {}
f = open('large_data/glove/glove.6B.300d.txt')
# save key/array pairs of the embeddings
#  the key of the dictionary is the word, the array is the embedding
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))

# now fill in the matrix, using the ordering from the
#  keras word tokenizer from before
found_words = 0
embedding_matrix = np.zeros((len(word_index) + 1, EMBED_SIZE))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
        found_words = found_words+1

print("Embedding Shape:",embedding_matrix.shape, "\n",
      "Total words found:",found_words, "\n",
      "Percentage:",100*found_words/embedding_matrix.shape[0])


# save this embedding now
embedding_layer = Embedding(len(word_index) + 1,
                            EMBED_SIZE,
                            weights=[embedding_matrix],
                            input_length=MAX_ART_LEN,
                            trainable=False)
# Out:
# Found 400000 word vectors.
# Embedding Shape: (66641, 300)
#  Total words found: 33598
#  Percentage: 50.41641031797242
# CPU times: user 13.1 s, sys: 394 ms, total: 13.4 s
# Wall time: 13.2 s

# %% [markdown]
# ### This is a RNN model using LSTM, which is called LSTM1

# %%
NUM_CLASSES = 1
rnn1 = Sequential(name='LSTM1')
rnn1.add(embedding_layer)
rnn1.add(LSTM(16))
rnn1.add(Dense(NUM_CLASSES, activation='sigmoid'))
rnn1.compile(loss='mean_squared_error', 
              optimizer='RMSprop', 
              metrics=['accuracy'])
rnn1.summary(line_length=90)
# Out:
# Metal device set to: Apple M1 Max
# Model: "LSTM1"
# __________________________________________________________________________________________
# Layer (type)                            Output Shape                        Param #
# ==========================================================================================
# embedding (Embedding)                   (None, 35, 300)                     19992300
# __________________________________________________________________________________________
# lstm (LSTM)                             (None, 16)                          20288
# __________________________________________________________________________________________
# dense (Dense)                           (None, 1)                           17
# ==========================================================================================
# Total params: 20,012,605
# Trainable params: 20,305
# Non-trainable params: 19,992,300
# __________________________________________________________________________________________
# 2021-11-15 14:47:09.904749: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-11-15 14:47:09.904855: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# %%time
rnn1_eval = evaluate_model(rnn1,X_train,y_train,X_test,y_test,rnn1.name,batch_size=1000,verbose=1)
# Out:
# Epoch 1/100
# 2021-11-15 14:47:10.058808: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-11-15 14:47:10.058974: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-11-15 14:47:10.438669: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:47:10.512843: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:47:10.599736: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 79/80 [============================>.] - ETA: 0s - loss: 0.2050 - accuracy: 0.6806
# 2021-11-15 14:47:13.320378: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:47:13.348951: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 80/80 [==============================] - 3s 36ms/step - loss: 0.2048 - accuracy: 0.6812 - val_loss: 0.1868 - val_accuracy: 0.7203
# Epoch 2/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1862 - accuracy: 0.7172 - val_loss: 0.1850 - val_accuracy: 0.7210
# Epoch 3/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1823 - accuracy: 0.7255 - val_loss: 0.1800 - val_accuracy: 0.7307
# Epoch 4/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1799 - accuracy: 0.7301 - val_loss: 0.1777 - val_accuracy: 0.7330
# Epoch 5/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1781 - accuracy: 0.7326 - val_loss: 0.1762 - val_accuracy: 0.7344
# Epoch 6/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1764 - accuracy: 0.7371 - val_loss: 0.1747 - val_accuracy: 0.7380
# Epoch 7/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1747 - accuracy: 0.7404 - val_loss: 0.1742 - val_accuracy: 0.7385
# Epoch 8/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1737 - accuracy: 0.7418 - val_loss: 0.1748 - val_accuracy: 0.7399
# Epoch 9/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1723 - accuracy: 0.7448 - val_loss: 0.1724 - val_accuracy: 0.7435
# Epoch 10/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1712 - accuracy: 0.7464 - val_loss: 0.1715 - val_accuracy: 0.7463
# Epoch 11/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1700 - accuracy: 0.7489 - val_loss: 0.1718 - val_accuracy: 0.7445
# Epoch 12/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1687 - accuracy: 0.7511 - val_loss: 0.1708 - val_accuracy: 0.7468
# Epoch 13/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1679 - accuracy: 0.7533 - val_loss: 0.1699 - val_accuracy: 0.7469
# Epoch 14/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1670 - accuracy: 0.7539 - val_loss: 0.1705 - val_accuracy: 0.7473
# Epoch 15/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1662 - accuracy: 0.7565 - val_loss: 0.1709 - val_accuracy: 0.7470
# Epoch 16/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1652 - accuracy: 0.7577 - val_loss: 0.1688 - val_accuracy: 0.7509
# Epoch 17/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1645 - accuracy: 0.7596 - val_loss: 0.1698 - val_accuracy: 0.7488
# Epoch 18/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1639 - accuracy: 0.7611 - val_loss: 0.1682 - val_accuracy: 0.7510
# Epoch 19/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1633 - accuracy: 0.7616 - val_loss: 0.1679 - val_accuracy: 0.7525
# Epoch 20/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1628 - accuracy: 0.7624 - val_loss: 0.1677 - val_accuracy: 0.7525
# Epoch 21/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1619 - accuracy: 0.7646 - val_loss: 0.1682 - val_accuracy: 0.7522
# Epoch 22/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1613 - accuracy: 0.7649 - val_loss: 0.1675 - val_accuracy: 0.7540
# Epoch 23/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1610 - accuracy: 0.7659 - val_loss: 0.1672 - val_accuracy: 0.7535
# Epoch 24/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1603 - accuracy: 0.7675 - val_loss: 0.1670 - val_accuracy: 0.7560
# Epoch 25/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1598 - accuracy: 0.7674 - val_loss: 0.1670 - val_accuracy: 0.7543
# Epoch 26/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1592 - accuracy: 0.7695 - val_loss: 0.1667 - val_accuracy: 0.7535
# Epoch 27/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1589 - accuracy: 0.7705 - val_loss: 0.1669 - val_accuracy: 0.7541
# Epoch 28/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1585 - accuracy: 0.7709 - val_loss: 0.1676 - val_accuracy: 0.7524
# Epoch 29/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1581 - accuracy: 0.7719 - val_loss: 0.1666 - val_accuracy: 0.7544
# Epoch 30/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1559 - accuracy: 0.7761 - val_loss: 0.1665 - val_accuracy: 0.7545
# Epoch 31/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1557 - accuracy: 0.7763 - val_loss: 0.1667 - val_accuracy: 0.7551
# Epoch 32/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1556 - accuracy: 0.7764 - val_loss: 0.1666 - val_accuracy: 0.7546
# Epoch 33/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1555 - accuracy: 0.7768 - val_loss: 0.1665 - val_accuracy: 0.7548
# Epoch 34/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7767 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 35/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 36/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1553 - accuracy: 0.7769 - val_loss: 0.1666 - val_accuracy: 0.7553
# 2021-11-15 14:48:48.708036: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:48:48.730102: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.76      9958
#            1       0.76      0.75      0.76     10042
#
#     accuracy                           0.76     20000
#    macro avg       0.76      0.76      0.76     20000
# weighted avg       0.76      0.76      0.76     20000
#
# CPU times: user 57.6 s, sys: 36.3 s, total: 1min 33s
# Wall time: 1min 42s

# %% [markdown]
# ### This is a RNN model using Bidirectional LSTM with dropouts and loss function and optimizer altered, which is called LSTM2

# %%
rnn1.save("lstm.h5")

# %% [markdown]
# ### This is a RNN model using GRU, which is called GRU1

# %%
rnn3 = Sequential(name='GRU1')
rnn3.add(embedding_layer)
rnn3.add(GRU(16))
rnn3.add(Dense(NUM_CLASSES, activation='sigmoid'))
rnn3.compile(loss='mean_squared_error', 
              optimizer='RMSprop', 
              metrics=['accuracy'])
rnn3.summary(line_length=90)
# Out:
# Model: "GRU1"
# __________________________________________________________________________________________
# Layer (type)                            Output Shape                        Param #
# ==========================================================================================
# embedding (Embedding)                   (None, 35, 300)                     19992300
# __________________________________________________________________________________________
# gru (GRU)                               (None, 16)                          15264
# __________________________________________________________________________________________
# dense_1 (Dense)                         (None, 1)                           17
# ==========================================================================================
# Total params: 20,007,581
# Trainable params: 15,281
# Non-trainable params: 19,992,300
# __________________________________________________________________________________________

# %%
# %%time
rnn3_eval = evaluate_model(rnn3,X_train,y_train,X_test,y_test,rnn3.name,batch_size=1000,verbose=1)
# Out:
# Epoch 1/100
# 2021-11-15 14:48:52.826787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:48:52.890350: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:48:52.963929: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 78/80 [============================>.] - ETA: 0s - loss: 0.2129 - accuracy: 0.6741
# 2021-11-15 14:48:55.022073: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:48:55.048088: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 80/80 [==============================] - 3s 27ms/step - loss: 0.2124 - accuracy: 0.6749 - val_loss: 0.1901 - val_accuracy: 0.7138
# Epoch 2/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1875 - accuracy: 0.7159 - val_loss: 0.1825 - val_accuracy: 0.7275
# Epoch 3/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.1838 - accuracy: 0.7243 - val_loss: 0.1807 - val_accuracy: 0.7290
# Epoch 4/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1823 - accuracy: 0.7275 - val_loss: 0.1800 - val_accuracy: 0.7272
# Epoch 5/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.1811 - accuracy: 0.7290 - val_loss: 0.1792 - val_accuracy: 0.7316
# Epoch 6/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1804 - accuracy: 0.7315 - val_loss: 0.1789 - val_accuracy: 0.7307
# Epoch 7/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1798 - accuracy: 0.7319 - val_loss: 0.1791 - val_accuracy: 0.7308
# Epoch 8/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1793 - accuracy: 0.7334 - val_loss: 0.1799 - val_accuracy: 0.7284
# Epoch 9/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1789 - accuracy: 0.7339 - val_loss: 0.1791 - val_accuracy: 0.7310
# Epoch 10/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1775 - accuracy: 0.7369 - val_loss: 0.1789 - val_accuracy: 0.7320
# Epoch 11/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.1774 - accuracy: 0.7367 - val_loss: 0.1789 - val_accuracy: 0.7321
# Epoch 12/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1774 - accuracy: 0.7367 - val_loss: 0.1789 - val_accuracy: 0.7321
# Epoch 13/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1773 - accuracy: 0.7371 - val_loss: 0.1789 - val_accuracy: 0.7322
# Epoch 14/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1773 - accuracy: 0.7371 - val_loss: 0.1789 - val_accuracy: 0.7321
# Epoch 15/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.1773 - accuracy: 0.7371 - val_loss: 0.1789 - val_accuracy: 0.7321
# Epoch 16/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.1772 - accuracy: 0.7372 - val_loss: 0.1789 - val_accuracy: 0.7320
# Epoch 17/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.1772 - accuracy: 0.7373 - val_loss: 0.1789 - val_accuracy: 0.7320
# 2021-11-15 14:49:24.617420: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:49:24.636999: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73      9958
#            1       0.73      0.74      0.73     10042
#
#     accuracy                           0.73     20000
#    macro avg       0.73      0.73      0.73     20000
# weighted avg       0.73      0.73      0.73     20000
#
# CPU times: user 29.1 s, sys: 18.6 s, total: 47.7 s
# Wall time: 35.2 s

# %% [markdown]
# ### This is a RNN model using Bidirectional GRU with dropouts and loss function and optimzer altered, which is called GRU2.

# %%
rnn3.save("gru.h5")

# %%
compare_model(rnn1_eval,rnn3_eval,rnn1.name,rnn3.name)
# Out:
# The difference on accuracy of LSTM1 and GRU1 is 0.014695060966026694,0.031804939033973294
# The difference on f1 score of LSTM1 and GRU1 is 0.012216954755757046,0.029297740629945803

# %% [markdown]
# ### Based on the roc curve, accuracy and F1 score comparison, the model GRU2 is better than GRU1. With 95% confidence, the GRU2 is also better.

# %% [markdown]
# ### With 95% confidence, the LSTM2 and GRU2 is not different statistically. But I like the GRU2, it seems slightly better on both accuracy and F1 score.

# %% [markdown]
# ### 2.2 Using the best RNN parameters and architecture, add a second recurrent chain to your RNN. The input to the second chain should be the output sequence of the first chain. Visualize the performance of training and validation sets versus the training iterations.

# %% [markdown]
# ### Since in this case, the LSTM and GRU is not different, I use GRU2 as my best model. Then I added another GRU on the previous model GRU2 and formed the model GRU3

# %% [markdown]
# ### With 95% confidence, the two models are statistically different and the GRU2 seems better. Based on the accuracy, F1 score and ROC curve, the model GRU2 also looks better than GRU3.

# %% [markdown]
# ## Exceptional Work (1 points total)
# - You have free reign to provide additional analyses.
# - One idea (required for 7000 level students to do one of these options):
#     - Option 1: Use dimensionality reduction (choose an appropriate method from this list: t-SNE, SVD, PCA, or UMAP) to visualize the word embeddings of a subset of words in your vocabulary that you expect to have an analogy that can be captured by the embedding. Try to interpret if an analogy exists, show the vectors that support/refute the analogy, and interpret your findings.
#     - Options 2: Use the ConceptNet Numberbatch embedding and compare to GloVe. Which method is better for your specific application?
# - Another Idea (NOT required): Try to create a RNN for generating novel text.

# %% [markdown]
# ### I used the ConceptNet Numberbatch embedding and compare to GloVe

# %%
# %%time
EMBED_SIZE = 300
# the embed size should match the file you load glove from
embeddings_index = {}
f = open('large_data/numberbatch-en-19.08.txt')
# save key/array pairs of the embeddings
#  the key of the dictionary is the word, the array is the embedding
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))

# now fill in the matrix, using the ordering from the
#  keras word tokenizer from before
found_words = 0
embedding_matrix = np.zeros((len(word_index) + 1, EMBED_SIZE))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
        found_words = found_words+1

print("Embedding Shape:",embedding_matrix.shape, "\n",
      "Total words found:",found_words, "\n",
      "Percentage:",100*found_words/embedding_matrix.shape[0])


# save this embedding now
embedding_layer = Embedding(len(word_index) + 1,
                            EMBED_SIZE,
                            weights=[embedding_matrix],
                            input_length=MAX_ART_LEN,
                            trainable=False)
# Out:
# Found 516783 word vectors.
# Embedding Shape: (66641, 300)
#  Total words found: 30516
#  Percentage: 45.79162977746432
# CPU times: user 16.5 s, sys: 403 ms, total: 16.9 s
# Wall time: 16.7 s

# %%
rnn6 = Sequential(name='GRU4')
rnn6.add(embedding_layer)
rnn6.add(Dropout(0.5))
rnn6.add(GRU(16))
rnn6.add(Dense(NUM_CLASSES, activation='sigmoid'))
rnn6.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
rnn6.summary(line_length=90)
# Out:
# Model: "GRU4"
# __________________________________________________________________________________________
# Layer (type)                            Output Shape                        Param #
# ==========================================================================================
# embedding_1 (Embedding)                 (None, 35, 300)                     19992300
# __________________________________________________________________________________________
# dropout (Dropout)                       (None, 35, 300)                     0
# __________________________________________________________________________________________
# gru_1 (GRU)                             (None, 16)                          15264
# __________________________________________________________________________________________
# dense_2 (Dense)                         (None, 1)                           17
# ==========================================================================================
# Total params: 20,007,581
# Trainable params: 15,281
# Non-trainable params: 19,992,300
# __________________________________________________________________________________________

# %%
# %%time
rnn6_eval = evaluate_model(rnn6,X_train,y_train,X_test,y_test,rnn6.name,batch_size=1000,verbose=1)
# Out:
# Epoch 1/100
# 2021-11-15 14:49:45.353943: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:49:45.419265: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:49:45.541413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 80/80 [==============================] - ETA: 0s - loss: 0.6652 - accuracy: 0.6298
# 2021-11-15 14:49:47.829311: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:49:47.857017: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 80/80 [==============================] - 3s 29ms/step - loss: 0.6652 - accuracy: 0.6298 - val_loss: 0.5936 - val_accuracy: 0.7014
# Epoch 2/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5795 - accuracy: 0.7026 - val_loss: 0.5431 - val_accuracy: 0.7458
# Epoch 3/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5686 - accuracy: 0.7107 - val_loss: 0.5352 - val_accuracy: 0.7443
# Epoch 4/100
# 80/80 [==============================] - 2s 26ms/step - loss: 0.5615 - accuracy: 0.7147 - val_loss: 0.5239 - val_accuracy: 0.7510
# Epoch 5/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5573 - accuracy: 0.7159 - val_loss: 0.5172 - val_accuracy: 0.7518
# Epoch 6/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5507 - accuracy: 0.7202 - val_loss: 0.5148 - val_accuracy: 0.7549
# Epoch 7/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5514 - accuracy: 0.7196 - val_loss: 0.5114 - val_accuracy: 0.7554
# Epoch 8/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5482 - accuracy: 0.7204 - val_loss: 0.5089 - val_accuracy: 0.7566
# Epoch 9/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5451 - accuracy: 0.7228 - val_loss: 0.5091 - val_accuracy: 0.7571
# Epoch 10/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5432 - accuracy: 0.7236 - val_loss: 0.5093 - val_accuracy: 0.7583
# Epoch 11/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5425 - accuracy: 0.7223 - val_loss: 0.5072 - val_accuracy: 0.7582
# Epoch 12/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5427 - accuracy: 0.7226 - val_loss: 0.5062 - val_accuracy: 0.7593
# Epoch 13/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5400 - accuracy: 0.7238 - val_loss: 0.5043 - val_accuracy: 0.7593
# Epoch 14/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5389 - accuracy: 0.7241 - val_loss: 0.5043 - val_accuracy: 0.7593
# Epoch 15/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5396 - accuracy: 0.7245 - val_loss: 0.5034 - val_accuracy: 0.7598
# Epoch 16/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5399 - accuracy: 0.7248 - val_loss: 0.5018 - val_accuracy: 0.7596
# Epoch 17/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5376 - accuracy: 0.7242 - val_loss: 0.5045 - val_accuracy: 0.7606
# Epoch 18/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5363 - accuracy: 0.7253 - val_loss: 0.5013 - val_accuracy: 0.7597
# Epoch 19/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5363 - accuracy: 0.7246 - val_loss: 0.5033 - val_accuracy: 0.7588
# Epoch 20/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5356 - accuracy: 0.7238 - val_loss: 0.4999 - val_accuracy: 0.7617
# Epoch 21/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5358 - accuracy: 0.7258 - val_loss: 0.5000 - val_accuracy: 0.7620
# Epoch 22/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5351 - accuracy: 0.7247 - val_loss: 0.5018 - val_accuracy: 0.7595
# Epoch 23/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5339 - accuracy: 0.7264 - val_loss: 0.5005 - val_accuracy: 0.7613
# Epoch 24/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5336 - accuracy: 0.7264 - val_loss: 0.4996 - val_accuracy: 0.7611
# Epoch 25/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5316 - accuracy: 0.7267 - val_loss: 0.4992 - val_accuracy: 0.7608
# Epoch 26/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5328 - accuracy: 0.7263 - val_loss: 0.4990 - val_accuracy: 0.7607
# Epoch 27/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5316 - accuracy: 0.7270 - val_loss: 0.4993 - val_accuracy: 0.7615
# Epoch 28/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5318 - accuracy: 0.7279 - val_loss: 0.4991 - val_accuracy: 0.7606
# Epoch 29/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5333 - accuracy: 0.7268 - val_loss: 0.4999 - val_accuracy: 0.7607
# Epoch 30/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5331 - accuracy: 0.7269 - val_loss: 0.4991 - val_accuracy: 0.7610
# Epoch 31/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5313 - accuracy: 0.7290 - val_loss: 0.4990 - val_accuracy: 0.7605
# Epoch 32/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5319 - accuracy: 0.7281 - val_loss: 0.4990 - val_accuracy: 0.7610
# Epoch 33/100
# 80/80 [==============================] - 2s 26ms/step - loss: 0.5317 - accuracy: 0.7281 - val_loss: 0.4990 - val_accuracy: 0.7610
# Epoch 34/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5339 - accuracy: 0.7261 - val_loss: 0.4990 - val_accuracy: 0.7609
# Epoch 35/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5321 - accuracy: 0.7260 - val_loss: 0.4990 - val_accuracy: 0.7610
# Epoch 36/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5330 - accuracy: 0.7272 - val_loss: 0.4990 - val_accuracy: 0.7609
# Epoch 37/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5309 - accuracy: 0.7265 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 38/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5328 - accuracy: 0.7270 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 39/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5335 - accuracy: 0.7251 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 40/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5327 - accuracy: 0.7280 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 41/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5313 - accuracy: 0.7278 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 42/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5332 - accuracy: 0.7273 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 43/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5323 - accuracy: 0.7259 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 44/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5330 - accuracy: 0.7270 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 45/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5314 - accuracy: 0.7272 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 46/100
# 80/80 [==============================] - 2s 25ms/step - loss: 0.5307 - accuracy: 0.7292 - val_loss: 0.4990 - val_accuracy: 0.7608
# Epoch 47/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.5321 - accuracy: 0.7274 - val_loss: 0.4990 - val_accuracy: 0.7608
# 2021-11-15 14:51:17.912025: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 14:51:17.932005: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75      9958
#            1       0.75      0.78      0.77     10042
#
#     accuracy                           0.76     20000
#    macro avg       0.76      0.76      0.76     20000
# weighted avg       0.76      0.76      0.76     20000
#
# CPU times: user 1min 14s, sys: 52 s, total: 2min 6s
# Wall time: 1min 36s

# %%
rnn6.save("gru_conceptNet.h5")

# %%
rnn7 = Sequential(name='LSTM4')
rnn7.add(embedding_layer)
rnn7.add(Dropout(0.5))
rnn7.add(LSTM(16))
rnn7.add(Dense(NUM_CLASSES, activation='sigmoid'))
rnn7.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
rnn7.summary(line_length=90)
# Out:
# Model: "LSTM4"
# __________________________________________________________________________________________
# Layer (type)                            Output Shape                        Param #
# ==========================================================================================
# embedding_1 (Embedding)                 (None, 35, 300)                     19992300
# __________________________________________________________________________________________
# dropout_1 (Dropout)                     (None, 35, 300)                     0
# __________________________________________________________________________________________
# lstm_1 (LSTM)                           (None, 16)                          20288
# __________________________________________________________________________________________
# dense_3 (Dense)                         (None, 1)                           17
# ==========================================================================================
# Total params: 20,012,605
# Trainable params: 20,305
# Non-trainable params: 19,992,300
# __________________________________________________________________________________________

# %%
# %%time
rnn7_eval = evaluate_model(rnn7,X_train,y_train,X_test,y_test,rnn6.name,batch_size=1000,verbose=1)
# Out:
# Epoch 1/100
# 2021-11-15 15:12:40.112971: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 15:12:40.182873: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 15:12:40.400827: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 80/80 [==============================] - ETA: 0s - loss: 0.6558 - accuracy: 0.6425
# 2021-11-15 15:12:43.479000: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 15:12:43.512476: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 80/80 [==============================] - 4s 39ms/step - loss: 0.6558 - accuracy: 0.6425 - val_loss: 0.5811 - val_accuracy: 0.7249
# Epoch 2/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5750 - accuracy: 0.7085 - val_loss: 0.5342 - val_accuracy: 0.7464
# Epoch 3/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5604 - accuracy: 0.7125 - val_loss: 0.5256 - val_accuracy: 0.7497
# Epoch 4/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5556 - accuracy: 0.7155 - val_loss: 0.5197 - val_accuracy: 0.7525
# Epoch 5/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5533 - accuracy: 0.7166 - val_loss: 0.5161 - val_accuracy: 0.7530
# Epoch 6/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5513 - accuracy: 0.7155 - val_loss: 0.5146 - val_accuracy: 0.7541
# Epoch 7/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5492 - accuracy: 0.7167 - val_loss: 0.5117 - val_accuracy: 0.7526
# Epoch 8/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5472 - accuracy: 0.7183 - val_loss: 0.5156 - val_accuracy: 0.7533
# Epoch 9/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5458 - accuracy: 0.7184 - val_loss: 0.5068 - val_accuracy: 0.7563
# Epoch 10/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5455 - accuracy: 0.7186 - val_loss: 0.5081 - val_accuracy: 0.7546
# Epoch 11/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5445 - accuracy: 0.7185 - val_loss: 0.5039 - val_accuracy: 0.7564
# Epoch 12/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5408 - accuracy: 0.7207 - val_loss: 0.5076 - val_accuracy: 0.7574
# Epoch 13/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5411 - accuracy: 0.7211 - val_loss: 0.5066 - val_accuracy: 0.7537
# Epoch 14/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5400 - accuracy: 0.7211 - val_loss: 0.5070 - val_accuracy: 0.7559
# Epoch 15/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5390 - accuracy: 0.7230 - val_loss: 0.5034 - val_accuracy: 0.7571
# Epoch 16/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5384 - accuracy: 0.7245 - val_loss: 0.5035 - val_accuracy: 0.7578
# Epoch 17/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5386 - accuracy: 0.7209 - val_loss: 0.5032 - val_accuracy: 0.7566
# Epoch 18/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5393 - accuracy: 0.7212 - val_loss: 0.5030 - val_accuracy: 0.7571
# Epoch 19/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5380 - accuracy: 0.7234 - val_loss: 0.5028 - val_accuracy: 0.7571
# Epoch 20/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5390 - accuracy: 0.7223 - val_loss: 0.5030 - val_accuracy: 0.7573
# Epoch 21/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5366 - accuracy: 0.7228 - val_loss: 0.5028 - val_accuracy: 0.7576
# Epoch 22/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5383 - accuracy: 0.7220 - val_loss: 0.5028 - val_accuracy: 0.7572
# Epoch 23/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5372 - accuracy: 0.7236 - val_loss: 0.5026 - val_accuracy: 0.7573
# Epoch 24/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5389 - accuracy: 0.7233 - val_loss: 0.5026 - val_accuracy: 0.7571
# Epoch 25/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5389 - accuracy: 0.7230 - val_loss: 0.5026 - val_accuracy: 0.7570
# Epoch 26/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5386 - accuracy: 0.7241 - val_loss: 0.5026 - val_accuracy: 0.7572
# Epoch 27/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5390 - accuracy: 0.7214 - val_loss: 0.5026 - val_accuracy: 0.7572
# Epoch 28/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5377 - accuracy: 0.7233 - val_loss: 0.5026 - val_accuracy: 0.7571
# Epoch 29/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5397 - accuracy: 0.7230 - val_loss: 0.5026 - val_accuracy: 0.7572
# Epoch 30/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5374 - accuracy: 0.7248 - val_loss: 0.5026 - val_accuracy: 0.7572
# Epoch 31/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5388 - accuracy: 0.7231 - val_loss: 0.5026 - val_accuracy: 0.7571
# 2021-11-15 15:14:09.096763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 15:14:09.117976: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75      9958
#            1       0.75      0.78      0.76     10042
#
#     accuracy                           0.76     20000
#    macro avg       0.76      0.76      0.76     20000
# weighted avg       0.76      0.76      0.76     20000
#
# CPU times: user 50.6 s, sys: 33.5 s, total: 1min 24s
# Wall time: 1min 32s

# %%
rnn7.save("lstm_conceptNet.h5")

# %% [markdown]
# ### With 95% confidence, the two models are not different statistically. However, I prefer the the model GRU2(with GloVe embedding), because of slightly higher F1 score and accuracy.

# %%
# compare_model(rnn6_eval,rnn4_eval,rnn6.name,rnn4.name)

# %%
from keras.models import load_model

rnn1_load = load_model("lstm.h5")
rnn1_load.summary(line_length=90)
# Out:
# Model: "LSTM1"
# __________________________________________________________________________________________
# Layer (type)                            Output Shape                        Param #
# ==========================================================================================
# embedding (Embedding)                   (None, 35, 300)                     19992300
# __________________________________________________________________________________________
# lstm (LSTM)                             (None, 16)                          20288
# __________________________________________________________________________________________
# dense (Dense)                           (None, 1)                           17
# ==========================================================================================
# Total params: 20,012,605
# Trainable params: 20,305
# Non-trainable params: 19,992,300
# __________________________________________________________________________________________

# %%
# %%time
rnn1_load_eval = evaluate_model(rnn1_load,X_train,y_train,X_test,y_test,rnn1_load.name,batch_size=1000,verbose=1)
# Out:
# Epoch 1/100
# 2021-11-15 15:02:49.559449: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 15:02:49.633180: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 15:02:49.779904: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 80/80 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.7770
# 2021-11-15 15:02:52.703312: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 15:02:52.734188: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 80/80 [==============================] - 4s 37ms/step - loss: 0.1553 - accuracy: 0.7770 - val_loss: 0.1666 - val_accuracy: 0.7552
# Epoch 2/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7552
# Epoch 3/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 4/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 5/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 6/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 7/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 8/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 9/100
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 10/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 11/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 12/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 13/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 14/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 15/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# Epoch 16/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1553 - accuracy: 0.7771 - val_loss: 0.1666 - val_accuracy: 0.7550
# 2021-11-15 15:03:33.838302: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-15 15:03:33.861175: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.75      9958
#            1       0.76      0.75      0.76     10042
#
#     accuracy                           0.76     20000
#    macro avg       0.76      0.76      0.75     20000
# weighted avg       0.76      0.76      0.76     20000
#
# CPU times: user 27.9 s, sys: 17 s, total: 44.9 s
# Wall time: 48.1 s
